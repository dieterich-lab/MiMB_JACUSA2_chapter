# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/alemsara/miniconda3/envs/snakemake/lib/python3.9/site-packages', '']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xb7\x0c\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cDoutput/snakemake/analysis/bivariate_tetR_metvstet/with_Cond1/LOF0.02\x94\x8cUoutput/snakemake/analysis/bivariate_tetR_metvstet.sampled300/DowS0/with_Cond1/LOF0.02\x94\x8cUoutput/snakemake/analysis/bivariate_tetR_metvstet.sampled300/DowS2/with_Cond1/LOF0.02\x94\x8caoutput/snakemake/analysis/bivariate_tetR_metvstet.sampled1000/DowS42/with_MixS0/0.1_Cond1/LOF0.02\x94\x8caoutput/snakemake/analysis/bivariate_tetR_metvstet.sampled1000/DowS42/with_MixS2/0.1_Cond1/LOF0.02\x94\x8caoutput/snakemake/analysis/bivariate_tetR_metvstet.sampled1000/DowS42/with_MixS0/0.5_Cond1/LOF0.02\x94\x8caoutput/snakemake/analysis/bivariate_tetR_metvstet.sampled1000/DowS42/with_MixS2/0.5_Cond1/LOF0.02\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x04inp1\x94K\x00N\x86\x94\x8c\x05inpt2\x94K\x01K\x03\x86\x94\x8c\x04inp3\x94K\x03K\x07\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x1c\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h")}\x94\x8c\x05_name\x94h\x1csNt\x94bh\x1dh h"\x85\x94R\x94(h")}\x94h&h\x1dsNt\x94bh\x14h\nh\x16h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\x0bh\x0ce}\x94(h\x12}\x94h\x1a]\x94(h\x1ch\x1deh\x1ch h"\x85\x94R\x94(h")}\x94h&h\x1csNt\x94bh\x1dh h"\x85\x94R\x94(h")}\x94h&h\x1dsNt\x94bubh\x18h-)\x81\x94(h\rh\x0eh\x0fh\x10e}\x94(h\x12}\x94h\x1a]\x94(h\x1ch\x1deh\x1ch h"\x85\x94R\x94(h")}\x94h&h\x1csNt\x94bh\x1dh h"\x85\x94R\x94(h")}\x94h&h\x1dsNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8cEoutput/snakemake/analysis/bivariate_tetR_metvstet_quantitave_analysis\x94a}\x94(h\x12}\x94h\x1a]\x94(h\x1ch\x1deh\x1ch h"\x85\x94R\x94(h")}\x94h&h\x1csNt\x94bh\x1dh h"\x85\x94R\x94(h")}\x94h&h\x1dsNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(]\x94\x8c\x03300\x94a]\x94(K,KnK\xadM \x01M\xc1\x01M$\x02e]\x94(\x8c\x010\x94\x8c\x012\x94e\x8c\x07T7-tetR\x94]\x94(\x8c\x030.1\x94\x8c\x030.5\x94e\x8c\x0242\x94\x8c\x041000\x94\x8c\rtetR_metvstet\x94\x8c\x03LOF\x94\x8c\x040.02\x94\x8c1output/snakemake/analysis/bivariate_tetR_metvstet\x94]\x94(\x8c\tPattern_1\x94\x8c\tPattern_2\x94ee}\x94(h\x12}\x94(\x8c\x12downsampling_thres\x94K\x00N\x86\x94\x8c\x06target\x94K\x01N\x86\x94\x8c\x05seeds\x94K\x02N\x86\x94\x8c\x03ref\x94K\x03N\x86\x94\x8c\x0cmixing_thres\x94K\x04N\x86\x94\x8c\x18mixing_downsampling_seed\x94K\x05N\x86\x94\x8c\x18mixing_downsampling_thre\x94K\x06N\x86\x94\x8c\x03lab\x94K\x07N\x86\x94\x8c\x06method\x94K\x08N\x86\x94\x8c\rcontamination\x94K\tN\x86\x94\x8c\x08inp_path\x94K\nN\x86\x94\x8c\x08features\x94K\x0bN\x86\x94uh\x1a]\x94(h\x1ch\x1deh\x1ch h"\x85\x94R\x94(h")}\x94h&h\x1csNt\x94bh\x1dh h"\x85\x94R\x94(h")}\x94h&h\x1dsNt\x94bhohZhqh\\hsh]huh`hwhahyhdh{heh}hfh\x7fhgh\x81hhh\x83hih\x85hjub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x12}\x94h\x1a]\x94(h\x1ch\x1deh\x1ch h"\x85\x94R\x94(h")}\x94h&h\x1csNt\x94bh\x1dh h"\x85\x94R\x94(h")}\x94h&h\x1dsNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x12}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x1a]\x94(h\x1ch\x1deh\x1ch h"\x85\x94R\x94(h")}\x94h&h\x1csNt\x94bh\x1dh h"\x85\x94R\x94(h")}\x94h&h\x1dsNt\x94bh\xa7K\x01h\xa9K\x01h\xabh\xa4ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h\x12}\x94h\x1a]\x94(h\x1ch\x1deh\x1ch h"\x85\x94R\x94(h")}\x94h&h\x1csNt\x94bh\x1dh h"\x85\x94R\x94(h")}\x94h&h\x1dsNt\x94bub\x8c\x06config\x94}\x94(\x8c\x05label\x94hf\x8c\x08path_jar\x94\x8c4/prj/Isabel_ONT_rRNA/software/JACUSA_v2.0.0-RC22.jar\x94\x8c\npicard_jar\x94\x8c$/biosw/picard-tools/2.5.0/picard.jar\x94\x8c\rjacusa_params\x94}\x94(\x8c\x01p\x94K\x10\x8c\x01D\x94\x8c\x00\x94\x8c\x01I\x94h\xd0\x8c\x02P1\x94\x8c\x0fFR-SECONDSTRAND\x94\x8c\x02P2\x94\x8c\x0fFR-SECONDSTRAND\x94\x8c\x01m\x94K\x01\x8c\x01q\x94K\x01\x8c\x01c\x94K\x04u\x8c\x08path_out\x94\x8c\x10output/snakemake\x94\x8c\x08path_inp\x94\x8c>/prj/Claudia_Hoebartner_WUE/tetR_and_blaR/Amina/data/tetR_blaR\x94\x8c\x08path_ref\x94\x8cS/prj/Claudia_Hoebartner_WUE/tetR_and_blaR/Amina/data/tetR_blaR/Wuerzburg_number1.fa\x94\x8c\x04data\x94}\x94(\x8c\x05cond1\x94]\x94\x8c\x15Ribozyme_teR-met_blaR\x94a\x8c\x05cond2\x94]\x94\x8c\x0ftetR-I_blaR-met\x94au\x8c\nNMF_params\x94}\x94(\x8c\x0eNMF_permuation\x94K\x04\x8c\x08nmf_rank\x94K\x03\x8c\x04nrun\x94K\x05\x8c\nrank_range\x94]\x94(K\x02K\x04e\x8c\x06thread\x94K\x06u\x8c\x04seed\x94]\x94(h^h_e\x8c\x08coverage\x94]\x94h[a\x8c\x0csampling_cov\x94he\x8c\rsampling_seed\x94hd\x8c\x0bmixing_thre\x94]\x94(hbhce\x8c\x06method\x94hg\x8c\rLOF_neighbors\x94]\x94(K\x14K<e\x8c\x11LOF_contamination\x94G?\x94z\xe1G\xae\x14{\x8c\x08mod_file\x94\x8cP/prj/Claudia_Hoebartner_WUE/tetR_and_blaR/Amina/data/tetR_blaR/mod_tetR_blaR.tsv\x94\x8c\x02id\x94h`\x8c\x06target\x94]\x94(K,KnK\xadM \x01M\xc1\x01M$\x02e\x8c\x05dtype\x94\x8c\x07Flongle\x94\x8c\x0bcombination\x94}\x94(\x8c\x07pattern\x94]\x94(K\x01K\x02e\x8c\x10external_pattern\x94h\xd0uu\x8c\x04rule\x94\x8c\x15quantitative_analysis\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94h\xd0ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/beegfs/homes/alemsara/RNAMod/JACUSA');
######## snakemake preamble end #########

# %% [markdown]
# # Quantitaive Analysis of Genetic Model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
downsampling_thres = snakemake.params[0]     # List of downsampling Read  Coverage 
target = snakemake.params[1]    # Target site
seeds = snakemake.params[2]       # List of samtools seeds for downsampling and mixing
ref = snakemake.params[3]           # Sequence ID
mixing_thres = snakemake.params[4]                 # List of modification rates
mixing_downsampling_seed = snakemake.params[5]    # Downsampling seed for the mixing samples
mixing_downsampling_thre = snakemake.params[6]   # Downsampling covcerage for the mixing samples
output =  snakemake.output[0]   # output folder
if not os.path.exists(output):
    os.makedirs(output, exist_ok=True)
output = output + "/"
label = snakemake.params[7]     # Analysis label
method = snakemake.params[8]      # Outlier detection method
contamination = str(snakemake.params[9])  # LOF contamination value
path_inp = snakemake.params[10]     #Path to inputs
features = snakemake.params.features
baseline= 'median'

# %% [markdown]
# ## Downasampling analysis

# %% [markdown]
# Generate barplots showing the diffrence between th target position and the median across different seeds of downsampling in terms of LOF scores.

# %%
def plot (ar, x_values, y_values, xerr_values=None,xlabel='', ylabel='',title ='', color ='#3288bd', path = '', legend = False):
    """
    plot function plot horizontal barplots from a dataframe columns
    """ 
    fig, axi= plt.subplots(figsize=(3,3), dpi = 300)
    ax = ar.plot(kind = "barh",x=x_values, y = y_values, legend = False, title = title, xerr = xerr_values , xlabel = xlabel,ax = axi)#     barp(arr) 
    ax.set_xlabel(ylabel)
    for s in ['top', 'right']:
        ax.spines[s].set_visible(False)
    if legend == True:
        plt.legend()
#     plt.show()
    plt.savefig(path+title + '.pdf' ,  bbox_inches = "tight") 
    plt.savefig(path+title+ '.eps'  ,  bbox_inches = "tight")

# %%
# label = 'blaR_metvsblaR'
# path_inp ='../../output/snakemake'+'/analysis/bivariate_'+label # path to input as in the config file
# output = '' # path to outputs
# downsampling_thres = ['300','500','1000','5000','10000'] # downsamplings coverage as set in config file
# # samples = { 'blaRvsblaR_met44':44,'blaRvsblaR_met110':110, 'blaRvsblaR_met173':173,'blaRvsblaR_met288':288,'blaRvsblaR_met449':449,'blaRvsblaR_met548':548} # list of analysis labels as set in the config file
# target = [45,245] # list of analysis labels as set in the config file
# seeds =['0','1','2','3','5','6','7','8','10','11','54321','42','11112021','20211025','123456789'] # list of seeds labels as set in the config file
# baseline = 'median' # median or the top value from the first downsampling
# mixing_thres = [0.1,0.25,0.5,0.75, 0.9] # list of mixing fraction of WT sample as set in the config file
# method = 'LOF'
# contamination ='0.01'
# ref = 'T7-blaR'
# mixing_downsampling_seed = '42'
# mixing_downsampling_thre ='1000'

# %%
for feat in features:
    for sl in target: 
        ar =[]
        df =[]
        state = True
        for thre in downsampling_thres: 
                tab = []
                for ij in seeds:
                    inp1 = path_inp+ '.sampled'+thre+'/DowS'+ij+'/with_Cond1/'+method+contamination+'/'+ feat+'_lof_scores.csv'
                    t = pd.read_csv(inp1, sep = ',',header = 0)
                    maxi = t.sort_values('scores').reset_index(drop= True).loc[0,'scores']
                    if baseline == 'median':
                        median = t['scores'].median()
                        val = t.loc[(t.pos - sl)==0,'scores'].values[0]
                        tab.append((median - val)/abs(maxi))
                    else:
                        if state == True: 
                            arr = t.sort_values('scores').reset_index(drop= True)
                            ref = arr[abs(arr.pos - sl) > 4].reset_index(drop = True).loc[0,'scores']
                            pos = arr[abs(arr.pos - sl) > 4].reset_index(drop = True).loc[0,'pos']
                            state = False
                        val = t.loc[(t.pos - sl)==0,'scores'].values[0]
                        tab.append((ref - val)/abs(maxi))
                df.append([int(thre),np.mean(tab),np.std(tab)] )  
        ar= pd.DataFrame(df, columns=['cov', 'scores', 'std'])
        title = "LOF_"+feat+"_Site:"+str(sl)
        plot(ar = ar, x_values= 'cov',y_values ="scores", xerr_values = 'std',xlabel = 'Read Coverage',  ylabel ='Distance', title = title, path = output)

# %% [markdown]
# Generate barplots showing the diffrence between th target position and the median in terms of combined features from JACUSA2 estimated scores.

# %%
for feat in features:
    for sl in target: 
        ar =[]
        df =[]
        for thre in downsampling_thres: 
                tab = []
                for ij in seeds:
                    inp1 = path_inp+ '.sampled'+thre+'/DowS'+ij+'/with_Cond1/'+method+contamination+'/prediction.out'         
                    t = pd.read_csv(inp1, sep = ',',header = 0)
                    t =t.loc[t.label == 'Cond1_Cond2', :]
#                     t =t.loc[t.label == label, :]
                    median = t[feat].median()
                    val = t.loc[(t.Ref_Pos == ref+ "_"+str(sl)),feat].values[0]
                    maxi = t.sort_values(feat,ascending = False ).reset_index(drop= True).loc[0,feat]
                    mini = t.sort_values(feat,ascending = True ).reset_index(drop= True).loc[0,feat]
                    tab.append((val - median)/(maxi-mini))
                
                df.append([int(thre),np.mean(tab),np.std(tab)] )  
        ar= pd.DataFrame(df, columns=['cov', feat, 'std'])
        title = "JACUSA_"+feat+"_Site:"+str(sl)
        plot(ar = ar, x_values= 'cov',y_values = feat, xerr_values = 'std', xlabel = 'Read Coverage', ylabel = 'Distance', title = title, path= output)

# %% [markdown]
# Generate barplots showing the fraction of detection of target position and its neighbors as outleirs across different seeds of downsamplings for different amount of reads.

# %%
for feat in features:
    for sl in target: 
        ar =[]
        df =[]
        for thre in downsampling_thres: 
                tab = pd.DataFrame([])
                for ij in seeds:
                    inp1 = path_inp+ '.sampled'+thre+'/DowS'+ij+'/with_Cond1/'+method+contamination+'/'+ feat+'_lof_scores.csv'
                    t = pd.read_csv(inp1, sep = ',',header = 0)
                    t =t.loc[t.outlier == True, :]
                    zz = t.loc[(t.pos - sl)== 0,:]
                    qq = t.loc[abs(t.pos - sl) < 3,:]
                    tab =tab.append([[qq.shape[0]/t.shape[0],zz.shape[0],qq.shape[0]!=0]])
                df.append([thre,np.mean(tab[0]),np.mean(tab[1]),np.mean(tab[2])] )  
        ar= pd.DataFrame(df, columns=['thre','5mer outliers fraction', 'site '+str(sl), '5mer'])
        title = "Downsapling Detection Frequency_"+feat+"_Site:"+str(sl)
        plot(ar, x_values='thre',y_values =['5mer', 'site '+str(sl)], xlabel = 'Read Coverage', ylabel = "Fraction detected as outliers", title = title, path = output, legend = True)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %% [markdown]
# ## Analysis of Mixtures WT/KO

# %% [markdown]
# Generate barplots showing the fraction of detection of target position and its neighbors as outleirs across different seeds of mixing for different mixing rates.

# %%
seeds = seeds[seeds!=mixing_downsampling_seed]
for feat in features:
    for sl in target: 
        ar =[]
        df =[]
        for thre in mixing_thres: 
                tab = pd.DataFrame([])
                for ij in seeds:
                    inp1 = path_inp+'.sampled'+mixing_downsampling_thre+'/DowS'+mixing_downsampling_seed+'/with_MixS'+ij+'/'+str(thre)+'_Cond1/'+method+contamination+'/'+feat+'_lof_scores.csv'         
                    t = pd.read_csv(inp1, sep = ',',header = 0)
                    t =t.loc[t.outlier == True, :]
                    zz = t.loc[(t.pos - sl)== 0,:]
                    qq = t.loc[abs(t.pos - sl) < 3,:]
                    tab =tab.append([[qq.shape[0]/t.shape[0],zz.shape[0],qq.shape[0]!=0]])
                df.append([thre,np.mean(tab[0]),np.mean(tab[1]),np.mean(tab[2])] )  
        ar= pd.DataFrame(df, columns=['thre','5mer outliers fraction', 'site '+str(sl), '5mer'])
        title = "Mixing Detection Frequency_"+feat+"_Site:"+str(sl)
        plot(ar, x_values='thre',y_values =['5mer', 'site '+str(sl)], xlabel = 'Modification Rate', ylabel = "Fraction detected as outliers", title = title, path = output, legend = True)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...
